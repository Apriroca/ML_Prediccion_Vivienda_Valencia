# %% [markdown]
# Bibliotecas y Configuración del Entorno

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Configuración personalizada para gráficos
plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# Preparación de Datos (Train/Test Split)

# %%
from sklearn.model_selection import train_test_split

# División del dataset (80% entrenamiento, 20% prueba)
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

# %% [markdown]
# Entrenamiento de Modelos Base (Regresión Lineal y Árbol de Decisión)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# Regresión Lineal
lin_reg = LinearRegression()
lin_reg.fit(X_train_scaled, y_train)

# Árbol de Decisión
tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(X_train_scaled, y_train)

# %% [markdown]
# Implementación de Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# Configuración y entrenamiento de Random Forest
# n_estimators=100 indica que usará 100 árboles
rf_reg = RandomForestRegressor(n_estimators=100, random_state=42)
rf_reg.fit(X_train_scaled, y_train)

# %% [markdown]
# Evaluación de Resultados

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Predicciones con Random Forest
predictions = rf_reg.predict(X_test_scaled)

# Cálculo de métricas
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predictions)

print(f"RMSE: {rmse}")
print(f"R2 Score: {r2}")

# %% [markdown]
# Análisis de Importancia de Características (Feature Importance)

# %%
# Obtención de la importancia de cada feature desde el modelo entrenado
importancias = pd.Series(rf_reg.feature_importances_, index=features)
top20 = importancias.sort_values(ascending=False).head(20)

# Visualización
top20.plot(kind='barh', title='Top 20 Variables más influyentes (Random Forest)')
